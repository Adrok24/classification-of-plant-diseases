# %% [markdown]
# <a href="https://colab.research.google.com/github/Adrok24/NN_exercises/blob/master/plants_disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Wed Nov 25 22:59:32 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.4 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
from zipfile import ZipFile 
import os

# %%
from google.colab import files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
folder = 'drive/My Drive/Plant_leaf_diseases_dataset_without_augmentation.zip'

# %%
plants_files_folder = "Plant_leave_diseases_dataset_without_augmentation"
with zipfile.ZipFile(folder,"r") as zip_ref:
    zip_ref.extractall("Plants")

# %%
base_dir = './Plants'

train_dir = os.path.join(base_dir, 'train')
os.makedirs(train_dir, exist_ok=True)

validation_dir = os.path.join(base_dir, 'validation')
os.makedirs(validation_dir, exist_ok=True)

test_dir = os.path.join(base_dir, 'test')
os.makedirs(test_dir, exist_ok=True)

# %%
plants_categories = os.listdir('/'.join((base_dir,plants_files_folder)))

# Creamos los directorios para las 39 clases presentes en el dataset
for directory in (train_dir, validation_dir, test_dir):
    for folder_name in plants_categories:
        name_split = folder_name.split('___') 
        plant_name = name_split[0]
        path_dir = ""
        if (len(name_split) > 1):
            plant_health = name_split[1]
            path_dir = os.path.join(directory, plant_health, plant_name)
        else:
            path_dir = os.path.join(directory, plant_name)
        os.makedirs(path_dir, exist_ok=True)

# %%
import shutil

for plant_category in plants_categories:
    plants_pictures = os.listdir('/'.join((base_dir,plants_files_folder, plant_category)))


    name_split = plant_category.split('___') 
    plant_name = name_split[0]
    path_dir = ""
    if (len(name_split) > 1):
        plant_health = name_split[1]
        path_dir = os.path.join( plant_health, plant_name)
    else:
        path_dir = os.path.join(plant_name)
    #print(path_dir)
    
    #Dividimos train 80%, validation 10% y test 10%. 
    train_ds = plants_pictures[:int(len(plants_pictures)*0.8)]
    val_ds = plants_pictures[int(len(plants_pictures)*0.8):int(len(plants_pictures)*0.9)]
    test_ds = plants_pictures[int(len(plants_pictures)*0.9):len(plants_pictures)]

    #Copio los porcentajes de cada clase en su correspondiente carpeta
    fnames = [i for i in train_ds]
    for fname in fnames:
        # try:
            src = os.path.join(base_dir,plants_files_folder, plant_category, fname)
            dst = os.path.join(base_dir,'train',path_dir, fname)
            shutil.copyfile(src, dst)
        # except OSError:
            pass

    
    fnames = [i for i in val_ds]
    for fname in fnames:
        # try:
            src = os.path.join(base_dir,plants_files_folder, plant_category, fname)
            dst = os.path.join(base_dir,'validation',path_dir, fname)
            shutil.copyfile(src, dst)      
        # except:
            pass


    fnames = [i for i in test_ds]
    for fname in fnames:
        # try:
            src = os.path.join(base_dir,plants_files_folder, plant_category, fname)
            dst = os.path.join(base_dir,'test',path_dir, fname)
            shutil.copyfile(src, dst)
                
        # except OSError:
            pass

# %%
#creamos DataFrames de train test y val
import pandas as pd
dict_train = {}
count_files = 0

for root, dirs, files in os.walk(train_dir, topdown=False):
    for name_file in files:
        dict_train[count_files] = {"file": os.path.join(root, name_file), "path": root, "health": root.split('/')[3], "type": root.split('/')[4] if len(root.split('/')) > 4 else root.split('/')[3]}
        count_files = count_files + 1

df_train = pd.DataFrame.from_dict(dict_train, "index")
display(df_train.shape)

dict_test = {}
count_files = 0

for root, dirs, files in os.walk(test_dir, topdown=False):
    for name_file in files:
        dict_test[count_files] = {"file": os.path.join(root, name_file), "path": root, "health": root.split('/')[3], "type": root.split('/')[4] if len(root.split('/')) > 4 else root.split('/')[3]}
        count_files = count_files + 1

df_test = pd.DataFrame.from_dict(dict_test, "index")
display(df_test.shape)

dict_validation = {}
count_files = 0

for root, dirs, files in os.walk(validation_dir, topdown=False):
    for name_file in files:
        dict_validation[count_files] = {"file": os.path.join(root, name_file), "path": root, "health": root.split('/')[3], "type": root.split('/')[4] if len(root.split('/')) > 4 else root.split('/')[3]}
        count_files = count_files + 1

df_validation = pd.DataFrame.from_dict(dict_validation, "index")
display(df_validation.shape)
# Out:
# (44343, 4)
# (5563, 4)
# (5542, 4)

# %%
df_train.health.hist(figsize=(18,5), xrot=80, bins=df_train.health.value_counts().shape[0] -1)

# %%
df_train.health.value_counts()
# Out:
# healthy                                 12062
# Haunglongbing_(Citrus_greening)          4405
# Bacterial_spot                           4335
# Tomato_Yellow_Leaf_Curl_Virus            4285
# Late_blight                              2327
# Powdery_mildew                           2309
# Early_blight                             1600
# Black_rot                                1440
# Septoria_leaf_spot                       1416
# Spider_mites Two-spotted_spider_mite     1340
# Target_Spot                              1123
# Esca_(Black_Measles)                     1106
# Common_rust                               953
# Background_without_leaves                 914
# Leaf_scorch                               887
# Leaf_blight_(Isariopsis_Leaf_Spot)        860
# Northern_Leaf_Blight                      788
# Leaf_Mold                                 761
# Apple_scab                                504
# Cercospora_leaf_spot Gray_leaf_spot       410
# Tomato_mosaic_virus                       298
# Cedar_apple_rust                          220
# Name: health, dtype: int64

# %%
df_train.type.hist(figsize=(10,5), xrot=80, bins=df_train.type.value_counts().shape[0] - 1)

# %%
df_train.type.value_counts()
# Out:
# Tomato                       14523
# Orange                        4405
# Soybean                       4072
# Grape                         3248
# Corn                          3080
# Apple                         2536
# Peach                         2125
# Pepper,_bell                  1979
# Potato                        1721
# Cherry                        1524
# Squash                        1468
# Strawberry                    1251
# Blueberry                     1201
# Background_without_leaves      914
# Raspberry                      296
# Name: type, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing import image

for index in np.random.choice(df_train.shape[0], 5):
  plant = df_train.iloc[index].file
  print(plant)
  plt.imshow(image.load_img(plant))
  plt.axis('off')
  plt.show()
# Out:
# ./Plants/train/healthy/Blueberry/image (314).JPG
# ./Plants/train/Apple_scab/Apple/image (467).JPG
# ./Plants/train/Septoria_leaf_spot/Tomato/image (364).JPG
# ./Plants/train/Powdery_mildew/Cherry/image (581).JPG
# ./Plants/train/Haunglongbing_(Citrus_greening)/Orange/image (1186).JPG

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
      rotation_range=25,
      width_shift_range=0.1,
      height_shift_range=0.1,
      shear_range=0.2,
      zoom_range=0.25,
      horizontal_flip=True,
      fill_mode='nearest')

# %%
# Elegimos una imagen para "aumentar"
img_path = df_train.iloc[-2].file

# La leemos y la reescalamos
img = image.load_img(img_path, target_size=(150, 150))

# La convertimos a un Numpy de forma (150, 150, 3)
x = image.img_to_array(img)

# La reescalamos a (1, 150, 150, 3)
x = x.reshape((1,) + x.shape)

# El comando .flow() genera batches de imágenes transformadas aleatoriamente
# Usamos un `break` para cortar el loop en algún momento
i = 0
for batch in datagen.flow(x, batch_size=1):
    plt.figure(i)
    imgplot = plt.imshow(image.array_to_img(batch[0]))
    plt.axis('off')
    i += 1
    if i % 4 == 0:
        break

# %%
from keras.preprocessing.image import ImageDataGenerator
data_dir = ""
# Reescalamos todas las imágenes en un factor de 1./255
train_datagen = ImageDataGenerator(
      rotation_range=25,
      width_shift_range=0.1,
      height_shift_range=0.1,
      shear_range=0.2,
      zoom_range=0.25,
      horizontal_flip=True,
      fill_mode='nearest',
      rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    df_train, # Referimos el df de train
    directory=data_dir, # El directorio donde se encuentran las imágenes
    x_col='file', # La columna con los path de los archivos
    y_col=['health', 'type'], # La variable con las labels
    target_size=(150, 150),
    classes=None, # Las clases se obtienen a partir de y_col
    class_mode='multi_output', # Se trata de un problema multi-output, multi-label
    batch_size=32
   )

val_generator = test_datagen.flow_from_dataframe(
    df_validation, # Referimos el df de validación
    directory=data_dir, # El directorio donde se encuentran las imágenes
    x_col='file', # La columna con los path de los archivos
    y_col=['health', 'type'], # La variable con las labels
    target_size=(150, 150),
    classes=None, # Las clases se obtienen a partir de y_col
    class_mode='multi_output', # Se trata de un problema multi-output, multi-label
    batch_size=32,
    shuffle=False
   )
# Out:
# Found 44343 validated image filenames.
# Found 5542 validated image filenames.

# %%
df_train
# Out:
#                                                     file  ...    type
# 0      ./Plants/train/Tomato_Yellow_Leaf_Curl_Virus/T...  ...  Tomato
# 1      ./Plants/train/Tomato_Yellow_Leaf_Curl_Virus/T...  ...  Tomato
# 2      ./Plants/train/Tomato_Yellow_Leaf_Curl_Virus/T...  ...  Tomato
# 3      ./Plants/train/Tomato_Yellow_Leaf_Curl_Virus/T...  ...  Tomato
# 4      ./Plants/train/Tomato_Yellow_Leaf_Curl_Virus/T...  ...  Tomato
# ...                                                  ...  ...     ...
# 44338     ./Plants/train/Apple_scab/Apple/image (87).JPG  ...   Apple
# 44339    ./Plants/train/Apple_scab/Apple/image (575).JPG  ...   Apple
# 44340    ./Plants/train/Apple_scab/Apple/image (193).JPG  ...   Apple
# 44341    ./Plants/train/Apple_scab/Apple/image (364).JPG  ...   Apple
# 44342    ./Plants/train/Apple_scab/Apple/image (258).JPG  ...   Apple
#
# [44343 rows x 4 columns]

# %%
#Testeamos nuestro generador
x, y = train_generator.next()
print('x shape: ',x.shape)
print('y1 shape: ',y[0].shape)
print('y2 shape: ',y[1].shape)
print('y1: ',y[0])
print('y2: ',y[1])
# Out:
# x shape:  (32, 150, 150, 3)
# y1 shape:  (32,)
# y2 shape:  (32,)
# y1:  ['Powdery_mildew' 'Septoria_leaf_spot' 'Northern_Leaf_Blight' 'healthy'
#  'healthy' 'healthy' 'Bacterial_spot' 'Late_blight' 'healthy'
#  'Leaf_blight_(Isariopsis_Leaf_Spot)' 'Tomato_Yellow_Leaf_Curl_Virus'
#  'healthy' 'Bacterial_spot' 'Apple_scab' 'healthy'
#  'Tomato_Yellow_Leaf_Curl_Virus' 'Early_blight'
#  'Haunglongbing_(Citrus_greening)' 'Early_blight' 'Early_blight'
#  'Leaf_scorch' 'Tomato_Yellow_Leaf_Curl_Virus' 'Early_blight'
#  'Tomato_Yellow_Leaf_Curl_Virus' 'Early_blight' 'Target_Spot' 'healthy'
#  'Tomato_Yellow_Leaf_Curl_Virus' 'Septoria_leaf_spot' 'Bacterial_spot'
#  'Haunglongbing_(Citrus_greening)' 'Bacterial_spot']
# y2:  ['Squash' 'Tomato' 'Corn' 'Soybean' 'Peach' 'Soybean' 'Peach' 'Tomato'
#  'Corn' 'Grape' 'Tomato' 'Strawberry' 'Tomato' 'Apple' 'Soybean' 'Tomato'
#  'Potato' 'Orange' 'Potato' 'Potato' 'Strawberry' 'Tomato' 'Potato'
#  'Tomato' 'Potato' 'Tomato' 'Raspberry' 'Tomato' 'Tomato' 'Tomato'
#  'Orange' 'Peach']

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
#Creamos un encoder para devolver valores de outputs en nuestro generador personalizado
heal_encoder = OneHotEncoder()
heal_encoder.fit(df_train['health'].to_numpy().reshape(-1, 1))
type_encoder = OneHotEncoder()
type_encoder.fit(df_train['type'].to_numpy().reshape(-1, 1))
# Out:
# OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='error', sparse=True)

# %%
def custom_generator(generator):
  while True:
    x, y = generator.next()
    y1_encoded = heal_encoder.transform(y[0].reshape(-1, 1)).toarray()
    y2_encoded = type_encoder.transform(y[1].reshape(-1, 1)).toarray()

    yield (x, [y1_encoded, y2_encoded])

# %%
# Importamos las clases Model e Input del módulo de modelos y capas, respectivamente
# %load_ext tensorboard
import tensorflow as tf
from tensorflow.keras.applications import ResNet101V2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, ZeroPadding2D, Conv2D, BatchNormalization, Activation, MaxPooling2D, GlobalAveragePooling2D, Add, Dense
from tensorflow.keras.initializers import he_normal
import datetime

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
# Importamos las clases Model e Input del módulo de modelos y capas, respectivamente
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, GlobalAveragePooling2D


health_utput_units =  df_train.health.value_counts().shape[0]
type_utput_units =  df_train.type.value_counts().shape[0]

# Definimos una variable que será una instancia de la clase Input
# donde especificamos las dimensiones de los datos de entrada
input_layer = Input(shape=(150, 150, 3))
# Definimos una variable distinta para cada capa del modelo
x = Conv2D(32, (3, 3), activation='relu')(input_layer)
x = MaxPooling2D((2, 2))(x)

########## HEALTH LAYERS
x_health = Conv2D(64, (3, 3), activation='relu')(x)
x_health = MaxPooling2D((2, 2))(x_health)

x_health = Conv2D(128, (3, 3), activation='relu')(x_health)
x_health = MaxPooling2D((2, 2))(x_health)

x_health = Conv2D(128, (3, 3), activation='relu')(x_health)
x_health = MaxPooling2D((2, 2))(x_health)

x_health = GlobalAveragePooling2D(name='avg_pool_health')(x_health)
x_health = Dense(512, activation='relu')(x_health)
health_output_layer = Dense(health_utput_units, activation='softmax', name='health_output')(x_health)
##########
########## TYPE LAYERS
x_type = Conv2D(64, (3, 3), activation='relu')(x)
x_type = MaxPooling2D((2, 2))(x_type)

x_type = Conv2D(128, (3, 3), activation='relu')(x_type)
x_type = MaxPooling2D((2, 2))(x_type)

x_type = Conv2D(128, (3, 3), activation='relu')(x_type)
x_type = MaxPooling2D((2, 2))(x_type)

x_type = GlobalAveragePooling2D(name='avg_pool_type')(x_type)
x_type = Dense(512, activation='relu')(x_type)
x_type_output_layer = Dense(type_utput_units, activation='softmax', name='type_output')(x_type)
##########

# Creamos la instancia del modelo multi-input
# Al haber múltiples entradas, definimos una lista de inputs
model = Model(input_layer, [health_output_layer,x_type_output_layer])

# %%
# Vemos que el summary del modelo es exactamente el mismo
# salvo que ahora se especifica la InputLayer, antes omitida
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 148, 148, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 74, 74, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 72, 72, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 72, 72, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 36, 36, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 36, 36, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 34, 34, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 34, 34, 128)  73856       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 128)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 17, 17, 128)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 15, 15, 128)  147584      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 15, 15, 128)  147584      max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 128)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 7, 7, 128)    0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# avg_pool_health (GlobalAverageP (None, 128)          0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# avg_pool_type (GlobalAveragePoo (None, 128)          0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          66048       avg_pool_health[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          66048       avg_pool_type[0][0]
# __________________________________________________________________________________________________
# health_output (Dense)           (None, 22)           11286       dense[0][0]
# __________________________________________________________________________________________________
# type_output (Dense)             (None, 15)           7695        dense_1[0][0]
# ==================================================================================================
# Total params: 631,845
# Trainable params: 631,845
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)

# %%
from keras import optimizers

model.compile(loss={'health_output' : 'categorical_crossentropy', 'type_output': 'categorical_crossentropy'}, 
              optimizer=optimizers.RMSprop(lr=1e-4),
              metrics={'health_output' : 'accuracy', 'type_output': 'accuracy'})

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Instanciamos nuestro objeto early_stopping
early_stopping = EarlyStopping(monitor='loss', min_delta=0.001, patience=10, restore_best_weights=True, verbose=1)

checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/Desafio II/labels_w/weights_m1_fix.{epoch:02d}-{val_loss:.2f}.h5', monitor='val_loss', verbose=0,
                             save_best_only=True, save_weights_only=False, mode='auto')

# Definimos una lista de callbacks
callbacks_list = [checkpoint, early_stopping]

# %%
spe = int(df_train.shape[0]/ 32) + 1
history = model.fit_generator(custom_generator(train_generator),
                              steps_per_epoch=spe,
                              epochs=40,
                              validation_data=custom_generator(val_generator),
                              validation_steps=100,
                              callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:From <ipython-input-31-b7cf8bdcd0a0>:7: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/40
# 1386/1386 [==============================] - 308s 222ms/step - loss: 4.0394 - health_output_loss: 2.1119 - type_output_loss: 1.9275 - health_output_accuracy: 0.3848 - type_output_accuracy: 0.4118 - val_loss: 3.1940 - val_health_output_loss: 1.3919 - val_type_output_loss: 1.8020 - val_health_output_accuracy: 0.6075 - val_type_output_accuracy: 0.4397
# Epoch 2/40
# 1386/1386 [==============================] - 308s 222ms/step - loss: 3.0528 - health_output_loss: 1.6303 - type_output_loss: 1.4225 - health_output_accuracy: 0.5012 - type_output_accuracy: 0.5436 - val_loss: 3.4577 - val_health_output_loss: 2.1646 - val_type_output_loss: 1.2930 - val_health_output_accuracy: 0.3251 - val_type_output_accuracy: 0.5939
# Epoch 3/40
# 1386/1386 [==============================] - 307s 221ms/step - loss: 2.5493 - health_output_loss: 1.3811 - type_output_loss: 1.1682 - health_output_accuracy: 0.5772 - type_output_accuracy: 0.6196 - val_loss: 2.1727 - val_health_output_loss: 1.0405 - val_type_output_loss: 1.1323 - val_health_output_accuracy: 0.6894 - val_type_output_accuracy: 0.6494
# Epoch 4/40
# 1386/1386 [==============================] - 306s 221ms/step - loss: 2.1613 - health_output_loss: 1.1718 - type_output_loss: 0.9895 - health_output_accuracy: 0.6377 - type_output_accuracy: 0.6783 - val_loss: 2.2411 - val_health_output_loss: 1.2511 - val_type_output_loss: 0.9900 - val_health_output_accuracy: 0.6112 - val_type_output_accuracy: 0.6733
# Epoch 5/40
# 1386/1386 [==============================] - 307s 221ms/step - loss: 1.8819 - health_output_loss: 1.0111 - type_output_loss: 0.8708 - health_output_accuracy: 0.6837 - type_output_accuracy: 0.7185 - val_loss: 2.1109 - val_health_output_loss: 1.2527 - val_type_output_loss: 0.8581 - val_health_output_accuracy: 0.6069 - val_type_output_accuracy: 0.7166
# Epoch 6/40
# 1386/1386 [==============================] - 306s 221ms/step - loss: 1.6845 - health_output_loss: 0.9025 - type_output_loss: 0.7820 - health_output_accuracy: 0.7166 - type_output_accuracy: 0.7452 - val_loss: 1.6849 - val_health_output_loss: 0.8449 - val_type_output_loss: 0.8400 - val_health_output_accuracy: 0.7577 - val_type_output_accuracy: 0.7369
# Epoch 7/40
# 1386/1386 [==============================] - 306s 221ms/step - loss: 1.5247 - health_output_loss: 0.8158 - type_output_loss: 0.7089 - health_output_accuracy: 0.7431 - type_output_accuracy: 0.7675 - val_loss: 2.2181 - val_health_output_loss: 1.3484 - val_type_output_loss: 0.8696 - val_health_output_accuracy: 0.5699 - val_type_output_accuracy: 0.7243
# Epoch 8/40
# 1386/1386 [==============================] - 306s 221ms/step - loss: 1.3960 - health_output_loss: 0.7468 - type_output_loss: 0.6492 - health_output_accuracy: 0.7625 - type_output_accuracy: 0.7881 - val_loss: 1.4182 - val_health_output_loss: 0.6191 - val_type_output_loss: 0.7991 - val_health_output_accuracy: 0.8172 - val_type_output_accuracy: 0.7475
# Epoch 9/40
# 1386/1386 [==============================] - 306s 221ms/step - loss: 1.2995 - health_output_loss: 0.6930 - type_output_loss: 0.6065 - health_output_accuracy: 0.7796 - type_output_accuracy: 0.8008 - val_loss: 1.9667 - val_health_output_loss: 1.2739 - val_type_output_loss: 0.6927 - val_health_output_accuracy: 0.6175 - val_type_output_accuracy: 0.7741
# Epoch 10/40
# 1386/1386 [==============================] - 306s 221ms/step - loss: 1.2124 - health_output_loss: 0.6471 - type_output_loss: 0.5654 - health_output_accuracy: 0.7927 - type_output_accuracy: 0.8142 - val_loss: 1.7014 - val_health_output_loss: 0.7895 - val_type_output_loss: 0.9119 - val_health_output_accuracy: 0.7644 - val_type_output_accuracy: 0.6994
# Epoch 11/40
# 1386/1386 [==============================] - 307s 221ms/step - loss: 1.1324 - health_output_loss: 0.6050 - type_output_loss: 0.5274 - health_output_accuracy: 0.8056 - type_output_accuracy: 0.8285 - val_loss: 1.3048 - val_health_output_loss: 0.7570 - val_type_output_loss: 0.5478 - val_health_output_accuracy: 0.7845 - val_type_output_accuracy: 0.8280
# Epoch 12/40
# 1386/1386 [==============================] - 306s 221ms/step - loss: 1.0650 - health_output_loss: 0.5687 - type_output_loss: 0.4963 - health_output_accuracy: 0.8193 - type_output_accuracy: 0.8388 - val_loss: 1.8425 - val_health_output_loss: 1.0350 - val_type_output_loss: 0.8075 - val_health_output_accuracy: 0.6938 - val_type_output_accuracy: 0.7553
# Epoch 13/40
# 1386/1386 [==============================] - 306s 221ms/step - loss: 1.0026 - health_output_loss: 0.5350 - type_output_loss: 0.4676 - health_output_accuracy: 0.8277 - type_output_accuracy: 0.8475 - val_loss: 1.0814 - val_health_output_loss: 0.4978 - val_type_output_loss: 0.5835 - val_health_output_accuracy: 0.8670 - val_type_output_accuracy: 0.8192
# Epoch 14/40
# 1386/1386 [==============================] - 308s 222ms/step - loss: 0.9540 - health_output_loss: 0.5066 - type_output_loss: 0.4474 - health_output_accuracy: 0.8370 - type_output_accuracy: 0.8535 - val_loss: 1.9328 - val_health_output_loss: 1.2363 - val_type_output_loss: 0.6965 - val_health_output_accuracy: 0.6572 - val_type_output_accuracy: 0.7697
# Epoch 15/40
# 1386/1386 [==============================] - 307s 222ms/step - loss: 0.9071 - health_output_loss: 0.4808 - type_output_loss: 0.4263 - health_output_accuracy: 0.8464 - type_output_accuracy: 0.8598 - val_loss: 1.1242 - val_health_output_loss: 0.4959 - val_type_output_loss: 0.6284 - val_health_output_accuracy: 0.8522 - val_type_output_accuracy: 0.8047
# Epoch 16/40
# 1386/1386 [==============================] - 305s 220ms/step - loss: 0.8595 - health_output_loss: 0.4541 - type_output_loss: 0.4054 - health_output_accuracy: 0.8523 - type_output_accuracy: 0.8687 - val_loss: 1.5250 - val_health_output_loss: 0.9962 - val_type_output_loss: 0.5288 - val_health_output_accuracy: 0.7322 - val_type_output_accuracy: 0.8258
# Epoch 17/40
# 1386/1386 [==============================] - 305s 220ms/step - loss: 0.8176 - health_output_loss: 0.4371 - type_output_loss: 0.3805 - health_output_accuracy: 0.8594 - type_output_accuracy: 0.8738 - val_loss: 1.8765 - val_health_output_loss: 1.0763 - val_type_output_loss: 0.8001 - val_health_output_accuracy: 0.7175 - val_type_output_accuracy: 0.7541
# Epoch 18/40
# 1386/1386 [==============================] - 304s 219ms/step - loss: 0.7758 - health_output_loss: 0.4138 - type_output_loss: 0.3620 - health_output_accuracy: 0.8662 - type_output_accuracy: 0.8812 - val_loss: 1.6467 - val_health_output_loss: 0.7641 - val_type_output_loss: 0.8825 - val_health_output_accuracy: 0.8078 - val_type_output_accuracy: 0.7634
# Epoch 19/40
# 1386/1386 [==============================] - 304s 219ms/step - loss: 0.7461 - health_output_loss: 0.3974 - type_output_loss: 0.3488 - health_output_accuracy: 0.8733 - type_output_accuracy: 0.8859 - val_loss: 1.2289 - val_health_output_loss: 0.7538 - val_type_output_loss: 0.4752 - val_health_output_accuracy: 0.7669 - val_type_output_accuracy: 0.8415
# Epoch 20/40
# 1386/1386 [==============================] - 306s 221ms/step - loss: 0.7168 - health_output_loss: 0.3830 - type_output_loss: 0.3337 - health_output_accuracy: 0.8778 - type_output_accuracy: 0.8912 - val_loss: 1.4148 - val_health_output_loss: 0.7662 - val_type_output_loss: 0.6485 - val_health_output_accuracy: 0.8194 - val_type_output_accuracy: 0.8112
# Epoch 21/40
# 1386/1386 [==============================] - 305s 220ms/step - loss: 0.6767 - health_output_loss: 0.3621 - type_output_loss: 0.3146 - health_output_accuracy: 0.8828 - type_output_accuracy: 0.8967 - val_loss: 1.7622 - val_health_output_loss: 1.0608 - val_type_output_loss: 0.7014 - val_health_output_accuracy: 0.7243 - val_type_output_accuracy: 0.7873
# Epoch 22/40
# 1386/1386 [==============================] - 305s 220ms/step - loss: 0.6506 - health_output_loss: 0.3505 - type_output_loss: 0.3001 - health_output_accuracy: 0.8871 - type_output_accuracy: 0.9026 - val_loss: 1.7509 - val_health_output_loss: 0.7942 - val_type_output_loss: 0.9566 - val_health_output_accuracy: 0.7897 - val_type_output_accuracy: 0.7403
# Epoch 23/40
# 1386/1386 [==============================] - 305s 220ms/step - loss: 0.6186 - health_output_loss: 0.3347 - type_output_loss: 0.2839 - health_output_accuracy: 0.8911 - type_output_accuracy: 0.9067 - val_loss: 0.9813 - val_health_output_loss: 0.6024 - val_type_output_loss: 0.3788 - val_health_output_accuracy: 0.8399 - val_type_output_accuracy: 0.8825
# Epoch 24/40
# 1386/1386 [==============================] - 305s 220ms/step - loss: 0.6022 - health_output_loss: 0.3255 - type_output_loss: 0.2767 - health_output_accuracy: 0.8961 - type_output_accuracy: 0.9094 - val_loss: 1.5670 - val_health_output_loss: 0.6996 - val_type_output_loss: 0.8674 - val_health_output_accuracy: 0.7825 - val_type_output_accuracy: 0.7659
# Epoch 25/40
# 1386/1386 [==============================] - 305s 220ms/step - loss: 0.5721 - health_output_loss: 0.3091 - type_output_loss: 0.2630 - health_output_accuracy: 0.8989 - type_output_accuracy: 0.9141 - val_loss: 1.0655 - val_health_output_loss: 0.3740 - val_type_output_loss: 0.6914 - val_health_output_accuracy: 0.9055 - val_type_output_accuracy: 0.7990
# Epoch 26/40
# 1386/1386 [==============================] - 306s 221ms/step - loss: 0.5596 - health_output_loss: 0.3053 - type_output_loss: 0.2543 - health_output_accuracy: 0.9019 - type_output_accuracy: 0.9170 - val_loss: 1.2217 - val_health_output_loss: 0.5926 - val_type_output_loss: 0.6291 - val_health_output_accuracy: 0.8091 - val_type_output_accuracy: 0.8066
# Epoch 27/40
# 1386/1386 [==============================] - 307s 221ms/step - loss: 0.5332 - health_output_loss: 0.2900 - type_output_loss: 0.2431 - health_output_accuracy: 0.9073 - type_output_accuracy: 0.9203 - val_loss: 0.7394 - val_health_output_loss: 0.3263 - val_type_output_loss: 0.4131 - val_health_output_accuracy: 0.8972 - val_type_output_accuracy: 0.8772
# Epoch 28/40
# 1386/1386 [==============================] - 306s 221ms/step - loss: 0.5105 - health_output_loss: 0.2806 - type_output_loss: 0.2299 - health_output_accuracy: 0.9093 - type_output_accuracy: 0.9259 - val_loss: 1.6339 - val_health_output_loss: 0.8393 - val_type_output_loss: 0.7946 - val_health_output_accuracy: 0.7624 - val_type_output_accuracy: 0.7861
# Epoch 29/40
# 1386/1386 [==============================] - 306s 221ms/step - loss: 0.4962 - health_output_loss: 0.2733 - type_output_loss: 0.2229 - health_output_accuracy: 0.9104 - type_output_accuracy: 0.9299 - val_loss: 1.2206 - val_health_output_loss: 0.5737 - val_type_output_loss: 0.6469 - val_health_output_accuracy: 0.8366 - val_type_output_accuracy: 0.8169
# Epoch 30/40
# 1386/1386 [==============================] - 306s 221ms/step - loss: 0.4791 - health_output_loss: 0.2644 - type_output_loss: 0.2147 - health_output_accuracy: 0.9141 - type_output_accuracy: 0.9302 - val_loss: 0.7773 - val_health_output_loss: 0.3651 - val_type_output_loss: 0.4122 - val_health_output_accuracy: 0.8995 - val_type_output_accuracy: 0.8756
# Epoch 31/40
# 1301/1386 [===========================>..] - ETA: 18s - loss: 0.4691 - health_output_loss: 0.2586 - type_output_loss: 0.2105 - health_output_accuracy: 0.9162 - type_output_accuracy: 0.9332Buffered data was truncated after reaching the output size limit.

# %%
model.save('drive/My Drive/Colab Notebooks/Desafio II/weights_m1_fix.h5')

# %%
acc = history.history['health_output_accuracy']
val_acc = history.history['val_health_output_accuracy']
loss = history.history['health_output_loss']
val_loss = history.history['val_health_output_loss']
epochs = range(1, len(acc) + 1)

plt.figure(figsize=(12,8))
plt.plot(epochs, acc, label='HEALTH Training accuracy')
plt.plot(epochs, val_acc, label='HEALTH Validation accuracy')
plt.xticks(ticks=epochs)
plt.title('HEALTH Training and validation accuracy')
plt.legend()

plt.figure(figsize=(12,8))
plt.plot(epochs, loss, label='HEALTH Training loss')
plt.plot(epochs, val_loss, label='HEALTH Validation loss')
plt.xticks(ticks=epochs)
plt.title('Training and validation loss')
plt.legend()
plt.show()
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py'>

# %%
acc = history.history['type_output_accuracy']
val_acc = history.history['val_type_output_accuracy']
loss = history.history['type_output_loss']
val_loss = history.history['val_type_output_loss']
epochs = range(1, len(acc) + 1)

plt.figure(figsize=(12,8))
plt.plot(epochs, acc, label='TYPE Training accuracy')
plt.plot(epochs, val_acc, label='TYPE Validation accuracy')
plt.xticks(ticks=epochs)
plt.title('TYPE Training and validation accuracy')
plt.legend()

plt.figure(figsize=(12,8))
plt.plot(epochs, loss, label='TYPE Training loss')
plt.plot(epochs, val_loss, label='TYPE Validation loss')
plt.xticks(ticks=epochs)
plt.title('Training and validation loss')
plt.legend()
plt.show()
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py'>

# %%
acc = history.history['val_type_output_accuracy']
val_acc = history.history['val_health_output_accuracy']
loss = history.history['val_type_output_loss']
val_loss = history.history['val_health_output_loss']
epochs = range(1, len(acc) + 1)

plt.figure(figsize=(12,8))
plt.plot(epochs, acc, label='Type Validation accuracy')
plt.plot(epochs, val_acc, label='Health Validation accuracy')
plt.xticks(ticks=epochs)
plt.title('COMPARE Type and Healt validation accuracy')
plt.legend()

plt.figure(figsize=(12,8))
plt.plot(epochs, loss, label='Type Validation loss')
plt.plot(epochs, val_loss, label='Health Validation loss')
plt.xticks(ticks=epochs)
plt.title('COMPARE Type and Healt Validation loss')
plt.legend()
plt.show()
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py'>

# %%
history.history
# Out:
# {'health_output_accuracy': [0.3848409056663513,
#   0.5011613965034485,
#   0.5771598815917969,
#   0.6376880407333374,
#   0.683738112449646,
#   0.7165505290031433,
#   0.7431387305259705,
#   0.7624878883361816,
#   0.7795819044113159,
#   0.792661726474762,
#   0.8056288361549377,
#   0.819272518157959,
#   0.8276616334915161,
#   0.8369753956794739,
#   0.8463793396949768,
#   0.8522878289222717,
#   0.8594141006469727,
#   0.8661569952964783,
#   0.8733057975769043,
#   0.877838671207428,
#   0.8828225135803223,
#   0.8870847821235657,
#   0.891076385974884,
#   0.8960602283477783,
#   0.8989017605781555,
#   0.9019010663032532,
#   0.9072683453559875,
#   0.9092979431152344,
#   0.9104255437850952,
#   0.9141014218330383,
#   0.916311502456665,
#   0.9196040034294128,
#   0.9211600422859192,
#   0.9266175031661987,
#   0.9257379770278931,
#   0.9283088445663452,
#   0.9308346509933472,
#   0.9314886331558228,
#   0.9331799745559692,
#   0.9345781803131104],
#  'health_output_loss': [2.1119067668914795,
#   1.6302884817123413,
#   1.3810927867889404,
#   1.1717842817306519,
#   1.0110853910446167,
#   0.9024877548217773,
#   0.8158147931098938,
#   0.7467746138572693,
#   0.6930253505706787,
#   0.6470603346824646,
#   0.6050200462341309,
#   0.568710207939148,
#   0.5350261330604553,
#   0.5066192746162415,
#   0.48084279894828796,
#   0.45405393838882446,
#   0.437124103307724,
#   0.41384047269821167,
#   0.39738228917121887,
#   0.38304051756858826,
#   0.36210235953330994,
#   0.3505234122276306,
#   0.33470046520233154,
#   0.32548826932907104,
#   0.30905747413635254,
#   0.3053267002105713,
#   0.29004696011543274,
#   0.28055456280708313,
#   0.27328118681907654,
#   0.2644215226173401,
#   0.25782981514930725,
#   0.2502087354660034,
#   0.23885135352611542,
#   0.2299535870552063,
#   0.2303817868232727,
#   0.22081851959228516,
#   0.21833068132400513,
#   0.21080714464187622,
#   0.209346204996109,
#   0.20390282571315765],
#  'loss': [4.039425849914551,
#   3.052797317504883,
#   2.549339532852173,
#   2.1612565517425537,
#   1.8818576335906982,
#   1.6844964027404785,
#   1.5247156620025635,
#   1.3959890604019165,
#   1.2994754314422607,
#   1.212424874305725,
#   1.1324043273925781,
#   1.0649778842926025,
#   1.002581000328064,
#   0.9539684057235718,
#   0.9070939421653748,
#   0.8594500422477722,
#   0.8175830841064453,
#   0.7758089900016785,
#   0.7461479306221008,
#   0.7167861461639404,
#   0.6766918301582336,
#   0.6505826115608215,
#   0.6185624599456787,
#   0.6021975874900818,
#   0.5720979571342468,
#   0.5595964789390564,
#   0.5331618785858154,
#   0.5104825496673584,
#   0.49619293212890625,
#   0.47913408279418945,
#   0.4679256081581116,
#   0.45439818501472473,
#   0.436135470867157,
#   0.4154534637928009,
#   0.4162195920944214,
#   0.39888089895248413,
#   0.39118319749832153,
#   0.3814559876918793,
#   0.37208566069602966,
#   0.3630754351615906],
#  'type_output_accuracy': [0.4118350148200989,
#   0.5436033010482788,
#   0.6195791959762573,
#   0.6782806515693665,
#   0.7185350656509399,
#   0.7452359795570374,
#   0.7674717307090759,
#   0.788106381893158,
#   0.8008479475975037,
#   0.8141984343528748,
#   0.8284960389137268,
#   0.8387795090675354,
#   0.8474844098091125,
#   0.8534605503082275,
#   0.859797477722168,
#   0.8686602115631104,
#   0.8738470673561096,
#   0.8811988234519958,
#   0.8859121203422546,
#   0.8911891579627991,
#   0.8966691493988037,
#   0.9026227593421936,
#   0.9067045450210571,
#   0.9093656539916992,
#   0.9140788912773132,
#   0.9169654846191406,
#   0.9203481674194336,
#   0.9258507490158081,
#   0.9299325942993164,
#   0.9301806092262268,
#   0.9331574440002441,
#   0.9343977570533752,
#   0.9355930089950562,
#   0.9390433430671692,
#   0.9399453997612,
#   0.9421554803848267,
#   0.9440723657608032,
#   0.9441174268722534,
#   0.9471844434738159,
#   0.9477933645248413],
#  'type_output_loss': [1.9275199174880981,
#   1.4225071668624878,
#   1.1682437658309937,
#   0.9894707798957825,
#   0.8707719445228577,
#   0.7820086479187012,
#   0.7089009284973145,
#   0.6492145657539368,
#   0.6064508557319641,
#   0.56536465883255,
#   0.5273847579956055,
#   0.4962678551673889,
#   0.4675551652908325,
#   0.4473501443862915,
#   0.42625051736831665,
#   0.4053971767425537,
#   0.3804589509963989,
#   0.3619689643383026,
#   0.3487658202648163,
#   0.33374616503715515,
#   0.3145895004272461,
#   0.30005910992622375,
#   0.28386130928993225,
#   0.2767091989517212,
#   0.2630411386489868,
#   0.25426867604255676,
#   0.2431149035692215,
#   0.22992777824401855,
#   0.22291138768196106,
#   0.21471306681632996,
#   0.21009624004364014,
#   0.20418943464756012,
#   0.1972840428352356,
#   0.1855001598596573,
#   0.1858375072479248,
#   0.17806236445903778,
#   0.17285233736038208,
#   0.17064885795116425,
#   0.16273938119411469,
#   0.15917247533798218],
#  'val_health_output_accuracy': [0.6075000166893005,
#   0.3251417875289917,
#   0.6893749833106995,
#   0.611216127872467,
#   0.6068750023841858,
#   0.7577189803123474,
#   0.5699433088302612,
#   0.817187488079071,
#   0.617517352104187,
#   0.7643749713897705,
#   0.7844990491867065,
#   0.6937500238418579,
#   0.8670447468757629,
#   0.657214879989624,
#   0.8521875143051147,
#   0.7321991324424744,
#   0.7174999713897705,
#   0.8078134655952454,
#   0.7668557167053223,
#   0.8193749785423279,
#   0.7243226170539856,
#   0.7896875143051147,
#   0.8399496078491211,
#   0.7825000286102295,
#   0.9054820537567139,
#   0.8090737462043762,
#   0.8971874713897705,
#   0.7624448537826538,
#   0.8365625143051147,
#   0.8994958996772766,
#   0.7306249737739563,
#   0.9237555265426636,
#   0.6414618492126465,
#   0.8609374761581421,
#   0.8667296767234802,
#   0.8228124976158142,
#   0.9054820537567139,
#   0.7841839790344238,
#   0.9303125143051147,
#   0.7882797718048096],
#  'val_health_output_loss': [1.3919237852096558,
#   2.164647340774536,
#   1.040480375289917,
#   1.2511188983917236,
#   1.252730369567871,
#   0.8449261784553528,
#   1.3484317064285278,
#   0.6191232204437256,
#   1.2739150524139404,
#   0.7895124554634094,
#   0.7569783926010132,
#   1.0350483655929565,
#   0.49781423807144165,
#   1.2363295555114746,
#   0.4958873689174652,
#   0.9961504340171814,
#   1.076306939125061,
#   0.7641400694847107,
#   0.7537671327590942,
#   0.7662349939346313,
#   1.0607750415802002,
#   0.7942491173744202,
#   0.6024145483970642,
#   0.6996212601661682,
#   0.3740409016609192,
#   0.5925901532173157,
#   0.32625389099121094,
#   0.8393442630767822,
#   0.5737341046333313,
#   0.3650663495063782,
#   1.0812785625457764,
#   0.26952385902404785,
#   1.8357216119766235,
#   0.4583304524421692,
#   0.4858633279800415,
#   0.6585740447044373,
#   0.40298086404800415,
#   0.962067723274231,
#   0.24347470700740814,
#   1.004912257194519],
#  'val_loss': [3.19395112991333,
#   3.457653284072876,
#   2.1727402210235596,
#   2.2410929203033447,
#   2.110862970352173,
#   1.6849300861358643,
#   2.218057632446289,
#   1.4182097911834717,
#   1.9666606187820435,
#   1.7014155387878418,
#   1.3048266172409058,
#   1.8425288200378418,
#   1.0813525915145874,
#   1.9327930212020874,
#   1.1242424249649048,
#   1.5249592065811157,
#   1.876450538635254,
#   1.6466766595840454,
#   1.2289220094680786,
#   1.4147615432739258,
#   1.762209177017212,
#   1.7508755922317505,
#   0.9812535643577576,
#   1.567022442817688,
#   1.0654759407043457,
#   1.2216622829437256,
#   0.7393965125083923,
#   1.6339119672775269,
#   1.220598578453064,
#   0.7772513628005981,
#   1.4169577360153198,
#   0.7371399402618408,
#   2.6310641765594482,
#   0.8066656589508057,
#   0.9503568410873413,
#   1.517938256263733,
#   0.8953275084495544,
#   1.2801525592803955,
#   0.5565298199653625,
#   1.3323432207107544],
#  'val_type_output_accuracy': [0.43968749046325684,
#   0.5938878655433655,
#   0.6493750214576721,
#   0.6732829213142395,
#   0.7165625095367432,
#   0.7369250059127808,
#   0.7243226170539856,
#   0.7475000023841858,
#   0.7741020917892456,
#   0.6993749737739563,
#   0.8279772996902466,
#   0.7553125023841858,
#   0.8191556334495544,
#   0.7696912288665771,
#   0.8046875,
#   0.8257718682289124,
#   0.7540624737739563,
#   0.763390064239502,
#   0.8415248990058899,
#   0.8112499713897705,
#   0.7873346209526062,
#   0.7403125166893005,
#   0.882482647895813,
#   0.7659375071525574,
#   0.7989917993545532,
#   0.8065532445907593,
#   0.8771874904632568,
#   0.7860743403434753,
#   0.8168749809265137,
#   0.8755513429641724,
#   0.8903124928474426,
#   0.8692501783370972,
#   0.7775677442550659,
#   0.8984375,
#   0.8692501783370972,
#   0.7628124952316284,
#   0.8648393154144287,
#   0.9010711908340454,
#   0.9046875238418579,
#   0.9089477062225342],
#  'val_type_output_loss': [1.8020269870758057,
#   1.293005108833313,
#   1.1322598457336426,
#   0.9899743795394897,
#   0.8581326007843018,
#   0.8400039076805115,
#   0.8696262836456299,
#   0.7990859746932983,
#   0.6927449703216553,
#   0.9119032025337219,
#   0.5478482842445374,
#   0.8074806928634644,
#   0.5835383534431458,
#   0.6964632272720337,
#   0.6283549666404724,
#   0.5288087725639343,
#   0.8001434206962585,
#   0.8825363516807556,
#   0.4751548171043396,
#   0.6485264301300049,
#   0.7014340758323669,
#   0.9566266536712646,
#   0.3788389563560486,
#   0.8674008250236511,
#   0.6914352774620056,
#   0.6290720701217651,
#   0.4131426513195038,
#   0.7945683002471924,
#   0.6468644738197327,
#   0.4121847450733185,
#   0.33567941188812256,
#   0.4676159918308258,
#   0.7953432202339172,
#   0.3483351171016693,
#   0.4644935429096222,
#   0.8593634963035583,
#   0.4923464059829712,
#   0.3180849254131317,
#   0.31305524706840515,
#   0.3274310827255249]}

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/drive/My Drive/Colab Notebooks/Desafio II/weights_m1_fix.h5')

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Utilizamos el Encoder para convertir el resultado de la predicción en un label

tick_labels_h = heal_encoder.categories_[0].tolist()
print(tick_labels_h[15])
tick_labels_t = type_encoder.categories_[0].tolist()
print(tick_labels_t[12])
# Out:
# Powdery_mildew
# Squash

# %%
from IPython.display import clear_output

# %%
# Generamos dos listas de predicciones para cada archivo en el set de Test
# Medimos el Accuracy de nuestro modelo

list_test_pred_health = []
list_test_pred_type= []
preds_true = 0
for index, plant in df_test.iterrows():
  img = image.load_img(plant.file, target_size=(150, 150))

  # La convertimos a un Numpy de forma (150, 150, 3)
  x = image.img_to_array(img)

  # La reescalamos a (1, 150, 150, 3)
  x = x.reshape((1,) + x.shape)

  batch = test_datagen.flow(x, batch_size=1)
  plt.figure(i)

  #imgplot = plt.imshow(image.array_to_img(batch[0][0]))
  health_pred, type_pred = model.predict(batch[0])
  health_pred_lbl = tick_labels_h[np.argmax(health_pred)]
  type_pred_lbl = tick_labels_t[np.argmax(type_pred)]
  list_test_pred_health.append(health_pred_lbl)
  list_test_pred_type.append(type_pred_lbl)
  
  # Medimos el Accuracy de nuestro modelo
  if plant.type + plant.health == type_pred_lbl + health_pred_lbl:
    preds_true += 1
  
  clear_output(wait=True)
  print('Accuracy:',np.round(preds_true / (index + 1), 3))

# %%
# Adjuntamos las predicciones al DataFrame de Test
df_test.loc[:,['healt_pred']] = list_test_pred_health
df_test.loc[:,['type_pred']] = list_test_pred_type

# %%
# Creamos dos columnas de predicciones concatenadas para luego evaluar en que porcentaje acertó tanto en el tipo de hoja como en la salud
df_test.loc[:,['concat_real']] = df_test.apply(lambda x: x.type + '__' + x.health, axis=1)
df_test.loc[:,['concat_pred']] = df_test.apply(lambda x: x.type_pred + '__' + x.healt_pred, axis=1)

# %%
df_test.to_csv('resNet_multi_output_TEST.csv')

# %%
# Matriz de Confusión de Health
print('Confusion Matrix')
cm = confusion_matrix(df_test.health, df_test.healt_pred)

plt.figure(figsize=(15,15))
sns.heatmap(cm, annot=True, fmt='.0f', square=True,
             xticklabels=tick_labels_h, yticklabels=tick_labels_h,
             cbar=False)
plt.ylabel('Etiqueta real')
plt.xlabel('Etiqueta predicha')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix

# %%
# Classification report
print('\nClassification Report:\n')
print(classification_report(df_test.health.to_numpy().flatten(), df_test.healt_pred.to_numpy().flatten(), target_names=tick_labels_h, digits = 2))
# Out:
# Classification Report:
#
#                                       precision    recall  f1-score   support
#
#                           Apple_scab       0.87      0.65      0.75        63
#            Background_without_leaves       0.97      0.97      0.97       115
#                       Bacterial_spot       0.90      0.74      0.81       543
#                            Black_rot       0.69      0.89      0.78       181
#                     Cedar_apple_rust       1.00      0.79      0.88        28
#  Cercospora_leaf_spot Gray_leaf_spot       0.76      0.71      0.73        52
#                          Common_rust       0.98      0.93      0.96       120
#                         Early_blight       0.83      0.72      0.77       200
#                 Esca_(Black_Measles)       0.86      0.97      0.91       139
#      Haunglongbing_(Citrus_greening)       1.00      0.95      0.97       551
#                          Late_blight       0.88      0.76      0.81       291
#                            Leaf_Mold       0.98      0.44      0.60        96
#   Leaf_blight_(Isariopsis_Leaf_Spot)       0.90      0.84      0.87       108
#                          Leaf_scorch       0.73      0.99      0.84       111
#                 Northern_Leaf_Blight       0.88      0.86      0.87        99
#                       Powdery_mildew       0.93      0.82      0.87       290
#                   Septoria_leaf_spot       0.74      0.81      0.78       178
# Spider_mites Two-spotted_spider_mite       0.91      0.40      0.55       168
#                          Target_Spot       0.85      0.28      0.43       141
#        Tomato_Yellow_Leaf_Curl_Virus       0.99      0.94      0.96       536
#                  Tomato_mosaic_virus       0.85      0.61      0.71        38
#                              healthy       0.78      0.99      0.87      1515
#
#                             accuracy                           0.86      5563
#                            macro avg       0.88      0.78      0.80      5563
#                         weighted avg       0.87      0.86      0.85      5563

# %%
# Matriz de Confusión de Type
print('Confusion Matrix')
cm = confusion_matrix(df_test.type, df_test.type_pred)

plt.figure(figsize=(15,15))
sns.heatmap(cm, annot=True, fmt='.0f', square=True,
             xticklabels=tick_labels_t, yticklabels=tick_labels_t,
             cbar=False)
plt.ylabel('Etiqueta real')
plt.xlabel('Etiqueta predicha')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix

# %%
# Classification report
print('\nClassification Report:\n')
print(classification_report(df_test.type.to_numpy().flatten(), df_test.type_pred.to_numpy().flatten(), target_names=tick_labels_t, digits = 2))
# Out:
# Classification Report:
#
#                            precision    recall  f1-score   support
#
#                     Apple       0.79      0.90      0.84       319
# Background_without_leaves       0.96      0.95      0.96       115
#                 Blueberry       0.95      0.93      0.94       151
#                    Cherry       0.99      0.79      0.88       192
#                      Corn       0.96      0.99      0.98       388
#                     Grape       0.90      0.93      0.91       408
#                    Orange       1.00      0.94      0.97       551
#                     Peach       0.95      0.68      0.79       266
#              Pepper,_bell       0.81      0.89      0.84       248
#                    Potato       0.90      0.69      0.78       216
#                 Raspberry       0.97      0.74      0.84        38
#                   Soybean       0.78      0.99      0.88       509
#                    Squash       0.94      0.94      0.94       184
#                Strawberry       0.79      0.96      0.86       157
#                    Tomato       0.95      0.93      0.94      1821
#
#                  accuracy                           0.91      5563
#                 macro avg       0.91      0.88      0.89      5563
#              weighted avg       0.92      0.91      0.91      5563

# %%
# Matriz de Confusión de las categorías concatenadas
print('Confusion Matrix')
cm = confusion_matrix(df_test.concat_real, df_test.concat_pred)

lbl_concat_preds = np.sort(df_test.concat_pred.unique())

plt.figure(figsize=(25,25))
sns.heatmap(cm, annot=True, fmt='.0f', square=True,
             xticklabels=lbl_concat_preds, yticklabels=lbl_concat_preds,
             cbar=False)
plt.ylabel('Etiqueta real')
plt.xlabel('Etiqueta predicha')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix

# %%
df_test.concat_pred.value_counts().tail(30)

# %%
# Classification report
print('\nClassification Report:\n')
print(classification_report(df_test.concat_real.to_numpy().flatten(), df_test.concat_pred.to_numpy().flatten(), target_names=lbl_concat_preds, digits = 2))
# Out:
# Classification Report:
#
#                                                       precision    recall  f1-score   support
#
#                                    Apple__Apple_scab       0.93      0.62      0.74        63
#                     Apple__Background_without_leaves       0.00      0.00      0.00         0
#                                Apple__Bacterial_spot       0.00      0.00      0.00         0
#                                     Apple__Black_rot       0.78      0.90      0.84        63
#                              Apple__Cedar_apple_rust       1.00      0.75      0.86        28
#           Apple__Cercospora_leaf_spot Gray_leaf_spot       0.00      0.00      0.00         0
#                                  Apple__Early_blight       0.00      0.00      0.00         0
#                          Apple__Esca_(Black_Measles)       0.00      0.00      0.00         0
#                                   Apple__Late_blight       0.00      0.00      0.00         0
#                          Apple__Northern_Leaf_Blight       0.00      0.00      0.00         0
#                                Apple__Powdery_mildew       0.00      0.00      0.00         0
#                            Apple__Septoria_leaf_spot       0.00      0.00      0.00         0
#                                       Apple__healthy       0.72      0.86      0.78       165
# Background_without_leaves__Background_without_leaves       0.99      0.93      0.96       115
#                 Background_without_leaves__Black_rot       0.00      0.00      0.00         0
#               Background_without_leaves__Late_blight       0.00      0.00      0.00         0
#                   Background_without_leaves__healthy       0.00      0.00      0.00         0
#                                 Blueberry__Black_rot       0.00      0.00      0.00         0
#                        Blueberry__Septoria_leaf_spot       0.00      0.00      0.00         0
#                       Blueberry__Tomato_mosaic_virus       0.00      0.00      0.00         0
#                                   Blueberry__healthy       0.98      0.93      0.96       151
#                               Cherry__Bacterial_spot       0.00      0.00      0.00         0
#                               Cherry__Powdery_mildew       1.00      0.84      0.91       106
#                                      Cherry__healthy       0.97      0.71      0.82        86
#                                 Corn__Bacterial_spot       0.00      0.00      0.00         0
#                                      Corn__Black_rot       0.00      0.00      0.00         0
#            Corn__Cercospora_leaf_spot Gray_leaf_spot       0.82      0.69      0.75        52
#                                    Corn__Common_rust       0.99      0.93      0.96       120
#                                   Corn__Early_blight       0.00      0.00      0.00         0
#                           Corn__Esca_(Black_Measles)       0.00      0.00      0.00         0
#                Corn__Haunglongbing_(Citrus_greening)       0.00      0.00      0.00         0
#                                    Corn__Late_blight       0.00      0.00      0.00         0
#             Corn__Leaf_blight_(Isariopsis_Leaf_Spot)       0.00      0.00      0.00         0
#                                    Corn__Leaf_scorch       0.00      0.00      0.00         0
#                           Corn__Northern_Leaf_Blight       0.89      0.86      0.87        99
#                                        Corn__healthy       0.97      0.99      0.98       117
#                                Grape__Bacterial_spot       0.00      0.00      0.00         0
#                                     Grape__Black_rot       0.83      0.86      0.84       118
#           Grape__Cercospora_leaf_spot Gray_leaf_spot       0.00      0.00      0.00         0
#                                  Grape__Early_blight       0.00      0.00      0.00         0
#                          Grape__Esca_(Black_Measles)       0.92      0.97      0.95       139
#               Grape__Haunglongbing_(Citrus_greening)       0.00      0.00      0.00         0
#                                   Grape__Late_blight       0.00      0.00      0.00         0
#            Grape__Leaf_blight_(Isariopsis_Leaf_Spot)       0.97      0.81      0.88       108
#                                   Grape__Leaf_scorch       0.00      0.00      0.00         0
#                                Grape__Powdery_mildew       0.00      0.00      0.00         0
#                 Grape__Tomato_Yellow_Leaf_Curl_Virus       0.00      0.00      0.00         0
#                                       Grape__healthy       0.72      0.60      0.66        43
#                               Orange__Bacterial_spot       0.00      0.00      0.00         0
#              Orange__Haunglongbing_(Citrus_greening)       1.00      0.91      0.95       551
#                                  Orange__Late_blight       0.00      0.00      0.00         0
#                               Orange__Powdery_mildew       0.00      0.00      0.00         0
#                Orange__Tomato_Yellow_Leaf_Curl_Virus       0.00      0.00      0.00         0
#                                      Orange__healthy       0.00      0.00      0.00         0
#                                    Peach__Apple_scab       0.00      0.00      0.00         0
#                                Peach__Bacterial_spot       0.95      0.66      0.78       230
#                                     Peach__Black_rot       0.00      0.00      0.00         0
#                                   Peach__Late_blight       0.00      0.00      0.00         0
#            Peach__Leaf_blight_(Isariopsis_Leaf_Spot)       0.00      0.00      0.00         0
#                                   Peach__Target_Spot       0.00      0.00      0.00         0
#                           Peach__Tomato_mosaic_virus       0.00      0.00      0.00         0
#                                       Peach__healthy       0.25      0.11      0.15        36
#              Pepper,_bell__Background_without_leaves       0.00      0.00      0.00         0
#                         Pepper,_bell__Bacterial_spot       0.90      0.61      0.73       100
#                              Pepper,_bell__Black_rot       0.00      0.00      0.00         0
#                           Pepper,_bell__Early_blight       0.00      0.00      0.00         0
#                   Pepper,_bell__Esca_(Black_Measles)       0.00      0.00      0.00         0
#        Pepper,_bell__Haunglongbing_(Citrus_greening)       0.00      0.00      0.00         0
#                            Pepper,_bell__Late_blight       0.00      0.00      0.00         0
#     Pepper,_bell__Leaf_blight_(Isariopsis_Leaf_Spot)       0.00      0.00      0.00         0
#                            Pepper,_bell__Leaf_scorch       0.00      0.00      0.00         0
#                         Pepper,_bell__Powdery_mildew       0.00      0.00      0.00         0
#                     Pepper,_bell__Septoria_leaf_spot       0.00      0.00      0.00         0
#          Pepper,_bell__Tomato_Yellow_Leaf_Curl_Virus       0.00      0.00      0.00         0
#                                Pepper,_bell__healthy       0.82      0.89      0.85       148
#                               Potato__Bacterial_spot       0.00      0.00      0.00         0
#                                    Potato__Black_rot       0.00      0.00      0.00         0
#          Potato__Cercospora_leaf_spot Gray_leaf_spot       0.00      0.00      0.00         0
#                                 Potato__Early_blight       0.94      0.85      0.89       100
#              Potato__Haunglongbing_(Citrus_greening)       0.00      0.00      0.00         0
#                                  Potato__Late_blight       0.91      0.43      0.59       100
#                                  Potato__Leaf_scorch       0.00      0.00      0.00         0
#                           Potato__Septoria_leaf_spot       0.00      0.00      0.00         0
#                                      Potato__healthy       0.22      0.25      0.24        16
#                                   Raspberry__healthy       0.97      0.74      0.84        38
#                                   Soybean__Black_rot       0.00      0.00      0.00         0
#                        Soybean__Esca_(Black_Measles)       0.00      0.00      0.00         0
#                                 Soybean__Late_blight       0.00      0.00      0.00         0
#                          Soybean__Septoria_leaf_spot       0.00      0.00      0.00         0
#        Soybean__Spider_mites Two-spotted_spider_mite       0.00      0.00      0.00         0
#                                 Soybean__Target_Spot       0.00      0.00      0.00         0
#                                     Soybean__healthy       0.79      0.99      0.88       509
#                                   Squash__Apple_scab       0.00      0.00      0.00         0
#                                 Squash__Early_blight       0.00      0.00      0.00         0
#                                  Squash__Late_blight       0.00      0.00      0.00         0
#                               Squash__Powdery_mildew       0.97      0.76      0.85       184
#                                      Squash__healthy       0.00      0.00      0.00         0
#                Strawberry__Background_without_leaves       0.00      0.00      0.00         0
#                           Strawberry__Bacterial_spot       0.00      0.00      0.00         0
#                             Strawberry__Early_blight       0.00      0.00      0.00         0
#                     Strawberry__Esca_(Black_Measles)       0.00      0.00      0.00         0
#          Strawberry__Haunglongbing_(Citrus_greening)       0.00      0.00      0.00         0
#                              Strawberry__Late_blight       0.00      0.00      0.00         0
#       Strawberry__Leaf_blight_(Isariopsis_Leaf_Spot)       0.00      0.00      0.00         0
#                              Strawberry__Leaf_scorch       0.91      0.98      0.94       111
#                           Strawberry__Powdery_mildew       0.00      0.00      0.00         0
#                       Strawberry__Septoria_leaf_spot       0.00      0.00      0.00         0
#                                  Strawberry__healthy       0.87      0.87      0.87        46
#                                   Tomato__Apple_scab       0.00      0.00      0.00         0
#                    Tomato__Background_without_leaves       0.00      0.00      0.00         0
#                               Tomato__Bacterial_spot       0.82      0.74      0.78       213
#                                    Tomato__Black_rot       0.00      0.00      0.00         0
#                             Tomato__Cedar_apple_rust       0.00      0.00      0.00         0
#          Tomato__Cercospora_leaf_spot Gray_leaf_spot       0.00      0.00      0.00         0
#                                  Tomato__Common_rust       0.00      0.00      0.00         0
#                                 Tomato__Early_blight       0.75      0.47      0.58       100
#                         Tomato__Esca_(Black_Measles)       0.00      0.00      0.00         0
#              Tomato__Haunglongbing_(Citrus_greening)       0.00      0.00      0.00         0
#                                  Tomato__Late_blight       0.76      0.70      0.73       191
#                                    Tomato__Leaf_Mold       0.98      0.44      0.60        96
#           Tomato__Leaf_blight_(Isariopsis_Leaf_Spot)       0.00      0.00      0.00         0
#                                  Tomato__Leaf_scorch       0.00      0.00      0.00         0
#                               Tomato__Powdery_mildew       0.00      0.00      0.00         0
#                           Tomato__Septoria_leaf_spot       0.76      0.77      0.77       178
#         Tomato__Spider_mites Two-spotted_spider_mite       0.92      0.39      0.55       168
#                                  Tomato__Target_Spot       0.89      0.28      0.42       141
#                Tomato__Tomato_Yellow_Leaf_Curl_Virus       0.99      0.93      0.96       536
#                          Tomato__Tomato_mosaic_virus       0.96      0.61      0.74        38
#                                      Tomato__healthy       0.37      0.98      0.53       160
#
#                                             accuracy                           0.80      5563
#                                            macro avg       0.26      0.22      0.23      5563
#                                         weighted avg       0.88      0.80      0.82      5563
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Obtenemos las predicciones equivocadas
bad_pred_mask = df_test.concat_real !=  df_test.concat_pred
bad_pred_mask.sum()

# %%
df_test[bad_pred_mask]
# Out:
#                                                    file  ...             concat_pred
# 7     ./Plants/test/Tomato_Yellow_Leaf_Curl_Virus/To...  ...         Tomato__healthy
# 55    ./Plants/test/Tomato_Yellow_Leaf_Curl_Virus/To...  ...  Tomato__Powdery_mildew
# 58    ./Plants/test/Tomato_Yellow_Leaf_Curl_Virus/To...  ...     Tomato__Late_blight
# 70    ./Plants/test/Tomato_Yellow_Leaf_Curl_Virus/To...  ...   Pepper,_bell__healthy
# 75    ./Plants/test/Tomato_Yellow_Leaf_Curl_Virus/To...  ...  Tomato__Powdery_mildew
# ...                                                 ...  ...                     ...
# 5551     ./Plants/test/Apple_scab/Apple/image (416).JPG  ...          Apple__healthy
# 5552     ./Plants/test/Apple_scab/Apple/image (487).JPG  ...   Peach__Bacterial_spot
# 5555     ./Plants/test/Apple_scab/Apple/image (288).JPG  ...          Apple__healthy
# 5556     ./Plants/test/Apple_scab/Apple/image (151).JPG  ...          Apple__healthy
# 5559     ./Plants/test/Apple_scab/Apple/image (187).JPG  ...          Apple__healthy
#
# [1101 rows x 8 columns]

# %%
# Iteramos y obtenemos las hoja reales vs una muestra de la prediccion
# Para visualizar los errores del modelo 
i = 0
for index, plant in df_test[bad_pred_mask].iterrows():

  img = image.load_img(plant.file, target_size=(150, 150))

  # La convertimos a un Numpy de forma (150, 150, 3)
  x = image.img_to_array(img)

  # La reescalamos a (1, 150, 150, 3)
  x = x.reshape((1,) + x.shape)

  batch = test_datagen.flow(x, batch_size=1) 

  type_mask = df_train.type == plant.type_pred 
  health_mask = df_train.health == plant.healt_pred
  example_pred = df_train[type_mask & health_mask].file

  # Si existe la combinacion entre hoja y estado de salud, imprimimos ambas imagenes
  if (example_pred.shape[0] > 0):
    print("Real: " + plant.type + "-" + plant.health + " | predicted: " + plant.type_pred + "-" + plant.healt_pred)
    plt.figure(i)
    imgplot = plt.imshow(image.array_to_img(batch[0][0]))
    plt.axis('off')
    plt.show()  
    print("Example prediction:")
    y_img = image.load_img(example_pred.iloc[0], target_size=(150, 150))
    y = image.img_to_array(y_img)
    y = y.reshape((1,) + y.shape)
    print(plant.type_pred + "-" + plant.healt_pred)
    Y_batch = test_datagen.flow(y, batch_size=1)
    Y_imgplot = plt.imshow(image.array_to_img(Y_batch[0][0]))
    plt.axis('off')
    plt.show()  
    print('######','\n\n')
  i += 1
  if i % 20 == 0:
      break

# %%
  type_mask = df_train.type == 'Apple'
  health_mask = df_train.health == 'healthy'
  example_pred = df_train[type_mask & health_mask].file

# %%
example_pred.iloc[0]
